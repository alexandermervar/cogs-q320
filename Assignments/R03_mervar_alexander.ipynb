# %% [markdown]
# # R03: Scientific Computation: Visualizing Data with Matplotlib

# %% [markdown]
# Alexander Mervar
# 2.3.2021

# %% [markdown]
# ### Generating a Plot

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel("Numbers")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# To be honest, this tutorial seemed pretty trivial and I feel comfortable with the task of graphing differnt data types. I feel like a little practice will result in me not even needing to look up the different styles.
